# %%
import pandas as pd 
import matplotlib.pyplot as plt 

def chroma_to_pitch(chroma):
    pitches=[]
    for i in chroma:
        if chroma==1:
            pitches.append("C")
        elif chroma==2:
            pitches.append("D")
df=pd.read_csv("/Users/macbook/Desktop/dataProjects/librosa_project2/features/audio_features.csv")
chroma_cols=[]
for col in df.columns:
    if col.startswith("chroma_"):
        chroma_cols.append(col)


df[chroma_cols].mean().plot(kind="bar",figsize=(10,4))
plt.title("Average Chroma Values(Pitch Class Intensity)")
plt.xlabel("Pitch Classes (C to B)")
plt.ylabel("Mean Intensity")
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 


df=pd.read_csv("/Users/macbook/Desktop/dataProjects/librosa_project2/features/audio_features.csv")
chroma_cols=[]
pitch_classes=["C","C#","D","D#","E","F","F#","G","G#","A","A#","B"]
chroma_mapping = {f"chroma_{i+1}": pitch_classes[i] for i in range(12)}

# 5. Rename the columns
df = df.rename(columns=chroma_mapping)

# Now you can access df["C"], df["A#"], etc.
df[pitch_classes].mean().plot(kind="bar", figsize=(10, 4), color="orchid")
plt.title("Average Pitch Class Energy")
plt.xlabel("Pitch Class")
plt.ylabel("Mean Intensity")
plt.xticks(rotation=0)
plt.grid(True)
plt.tight_layout()
plt.show()
